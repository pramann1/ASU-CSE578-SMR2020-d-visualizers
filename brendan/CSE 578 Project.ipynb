# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
Color = []
Color2 = []
count1 = 0
for q in range(0, len(df), 1):
    if df['Income'][q] == " >50K":
        if df['Race'][q] == " Black":
            Color.append(1)
        elif df['Race'][q] == " White":
            Color.append(2)
        elif df['Race'][q] == " Amer-Indian-Eskimo":
            Color.append(3)
        elif df['Race'][q] == " Asian-Pac-Islander":
            Color.append(4)
        else:
            Color.append(5)
    else:
        if df['Race'][q] == " Black":
            Color2.append(1)
        elif df['Race'][q] == " White":
            Color2.append(2)
        elif df['Race'][q] == " Amer-Indian-Eskimo":
            Color2.append(3)
        elif df['Race'][q] == " Asian-Pac-Islander":
            Color2.append(4)
        else:
            Color2.append(5)
import numpy as np
import matplotlib.pyplot as plt
plt.hist(Color, bins=5)
plt.xticks([1, 2, 3, 4, 5], ['Black', 'White', 'American Indian', 'Asian Pacific Islander', 'Other'], rotation = 90)
plt.title("Histogram of Income >50K")
plt.show()
plt.close()
plt.hist(Color2, bins=5)
plt.xticks([1, 2, 3, 4, 5], ['Black', 'White', 'American Indian', 'Asian Pacific Islander', 'Other'], rotation = 90)
plt.title("Histogram of Income <=50K")
plt.savefig("Histogram <=50K")
plt.show()
plt.close()

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
JobArray = [0] * 8
LabelList = []
countFed = 0
ArrayFed = [0] * 4
countLoc = 0
ArrayLoc = [0] * 4
countquestion = 0
Arrayquestion = [0] * 4
countinc = 0
Arrayinc = [0] * 4
countNever = 0
ArrayNever = [0] * 4
countnotinc = 0
Arraynotinc = [0] * 4
countPrivate = 0
ArrayPrivate = [0] * 4
countState = 0
ArrayState = [0] * 4
for i in range(0, len(df), 1):
    if df['Employment'][i] == " Federal-gov":
        JobArray[3] += 1
        if "Federal-gov" not in LabelList:
            LabelList.append("Federal-gov")
        countFed += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayFed[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayFed[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayFed[2] += 1
        else:
            ArrayFed[3] += 1
    elif df['Employment'][i] == " Local-gov":
        JobArray[4] += 1
        if "Local-gov" not in LabelList:
            LabelList.append("Local-gov")
        countLoc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayLoc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayLoc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayLoc[2] += 1
        else:
            ArrayLoc[3] += 1
    elif df['Employment'][i] == " ?":
        JobArray[5] += 1
        if "?" not in LabelList:
            LabelList.append("?")
        countquestion += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Arrayquestion[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Arrayquestion[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Arrayquestion[2] += 1
        else:
            Arrayquestion[3] += 1
    elif df['Employment'][i] == " Self-emp-inc":
        JobArray[6] += 1
        if "Self-emp-inc" not in LabelList:
            LabelList.append("Self-emp-inc")
        countinc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Arrayinc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Arrayinc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Arrayinc[2] += 1
        else:
            Arrayinc[3] += 1
    elif df['Employment'][i] == " Never-worked":
        JobArray[7] += 1
        if "Never-worked" not in LabelList:
            LabelList.append("Never-worked")
        countNever += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayNever[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayNever[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayNever[2] += 1
        else:
            ArrayNever[3] += 1
    elif df['Employment'][i][1::] == "Self-emp-not-inc":
        JobArray[0] += 1
        if "Self-emp-not-inc" not in LabelList:
            LabelList.append("Self-emp-not-inc")
        countnotinc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Arraynotinc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Arraynotinc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Arraynotinc[2] += 1
        else:
            Arraynotinc[3] += 1
    elif df['Employment'][i][1::] == "Private":
        JobArray[1] += 1
        if "Private" not in LabelList:
            LabelList.append("Private")
        countPrivate += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayPrivate[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayPrivate[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayPrivate[2] += 1
        else:
            ArrayPrivate[3] += 1
    elif df['Employment'][i] == "State-gov" or " State-gov":
        JobArray[2] += 1
        if "State-gov" not in LabelList:
            LabelList.append("State-gov")
        countState += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayState[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayState[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayState[2] += 1
        else:
            ArrayState[3] += 1
List = []
for i in range(0, len(df), 1):
    if df['Employment'][i] not in List:
        List.append(df['Employment'][i])
q = []
for i in range(0, (len(List) - 1), 1):
    q.append(List[i][1::])
for i in range(0, 4, 1):
    if i == 0:
        extradf1 = pd.DataFrame(np.c_[(Arraynotinc[i] / countnotinc), (ArrayPrivate[i] / countPrivate), (ArrayState[i] / countState), (ArrayFed[i] / countFed), (ArrayLoc[i] / countLoc), (Arrayquestion[i]/countquestion), (Arrayinc[i]/countinc), (ArrayNever[i]/countNever)], index = [" < 30"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Number of People')
        plt.title(('Hours Worked by Job Type'))
        plt.show()
        plt.close()
    if i == 1:
        extradf1 = pd.DataFrame(np.c_[(Arraynotinc[i] / countnotinc), (ArrayPrivate[i] / countPrivate), (ArrayState[i] / countState), (ArrayFed[i] / countFed), (ArrayLoc[i] / countLoc), (Arrayquestion[i]/countquestion), (Arrayinc[i]/countinc), (ArrayNever[i]/countNever)], index = ["30 - 40"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Number of People')
        plt.title(('Hours Worked by Job Type'))
        plt.show()
        plt.close()
    if i == 2:
        extradf1 = pd.DataFrame(np.c_[(Arraynotinc[i] / countnotinc), (ArrayPrivate[i] / countPrivate), (ArrayState[i] / countState), (ArrayFed[i] / countFed), (ArrayLoc[i] / countLoc), (Arrayquestion[i]/countquestion), (Arrayinc[i]/countinc), (ArrayNever[i]/countNever)], index = ["40-80"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Number of People')
        plt.title(('Hours Worked by Job Type'))
        plt.show()
        plt.close()
    if i == 3:
        extradf1 = pd.DataFrame(np.c_[(Arraynotinc[i] / countnotinc), (ArrayPrivate[i] / countPrivate), (ArrayState[i] / countState), (ArrayFed[i] / countFed), (ArrayLoc[i] / countLoc), (Arrayquestion[i]/countquestion), (Arrayinc[i]/countinc), (ArrayNever[i]/countNever)], index = ["80+"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Number of People')
        plt.title(('Hours Worked by Job Type'))
        plt.show()
        plt.close()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:205: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:215: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
JobArray = [0] * 8
LabelList = []
countFed = 0
ArrayFed = [0] * 4
countLoc = 0
ArrayLoc = [0] * 4
countquestion = 0
Arrayquestion = [0] * 4
countinc = 0
Arrayinc = [0] * 4
countNever = 0
ArrayNever = [0] * 4
countnotinc = 0
Arraynotinc = [0] * 4
countPrivate = 0
ArrayPrivate = [0] * 4
countState = 0
ArrayState = [0] * 4
for i in range(0, len(df), 1):
    if df['Employment'][i] == " Federal-gov":
        JobArray[3] += 1
        if "Federal-gov" not in LabelList:
            LabelList.append("Federal-gov")
        countFed += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayFed[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayFed[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayFed[2] += 1
        else:
            ArrayFed[3] += 1
    elif df['Employment'][i] == " Local-gov":
        JobArray[4] += 1
        if "Local-gov" not in LabelList:
            LabelList.append("Local-gov")
        countLoc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayLoc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayLoc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayLoc[2] += 1
        else:
            ArrayLoc[3] += 1
    elif df['Employment'][i] == " ?":
        JobArray[5] += 1
        if "?" not in LabelList:
            LabelList.append("?")
        countquestion += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Arrayquestion[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Arrayquestion[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Arrayquestion[2] += 1
        else:
            Arrayquestion[3] += 1
    elif df['Employment'][i] == " Self-emp-inc":
        JobArray[6] += 1
        if "Self-emp-inc" not in LabelList:
            LabelList.append("Self-emp-inc")
        countinc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Arrayinc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Arrayinc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Arrayinc[2] += 1
        else:
            Arrayinc[3] += 1
    elif df['Employment'][i] == " Never-worked":
        JobArray[7] += 1
        if "Never-worked" not in LabelList:
            LabelList.append("Never-worked")
        countNever += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayNever[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayNever[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayNever[2] += 1
        else:
            ArrayNever[3] += 1
    elif df['Employment'][i][1::] == "Self-emp-not-inc":
        JobArray[0] += 1
        if "Self-emp-not-inc" not in LabelList:
            LabelList.append("Self-emp-not-inc")
        countnotinc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Arraynotinc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Arraynotinc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Arraynotinc[2] += 1
        else:
            Arraynotinc[3] += 1
    elif df['Employment'][i][1::] == "Private":
        JobArray[1] += 1
        if "Private" not in LabelList:
            LabelList.append("Private")
        countPrivate += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayPrivate[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayPrivate[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayPrivate[2] += 1
        else:
            ArrayPrivate[3] += 1
    elif df['Employment'][i] == "State-gov" or " State-gov":
        JobArray[2] += 1
        if "State-gov" not in LabelList:
            LabelList.append("State-gov")
        countState += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayState[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayState[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayState[2] += 1
        else:
            ArrayState[3] += 1
List = []
for i in range(0, len(df), 1):
    if df['Employment'][i] not in List:
        List.append(df['Employment'][i])
q = []
for i in range(0, (len(List) - 1), 1):
    q.append(List[i][1::])
fig, ax1 = plt.subplots(figsize = (24,12)) 
ax1.pie(JobArray, autopct= "%.1f%%" )
ax1.legend(LabelList, loc = "upper right", fontsize = 16)
plt.title("Types of Employment", fontsize = 24)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
Array = [0] * 7
LabelList = []
for i in range(0, len(df), 1):
    if df['Marital Status'][i] == " Married-civ-spouse":
        Array[0] += 1
        if "Married-civ-spouse" not in LabelList:
            LabelList.append("Married-civ-spouse")
    elif df['Marital Status'][i] == " Divorced":
        Array[1] += 1
        if "Divorced" not in LabelList:
            LabelList.append("Divorced")
    elif df['Marital Status'][i] == " Married-spouse-absent":
        Array[2] += 1
        if "Married-spouse-absent" not in LabelList:
            LabelList.append("Married-spouse-absent")
    elif df['Marital Status'][i] == " Never-married":
        Array[3] += 1
        if "Never-married" not in LabelList:
            LabelList.append("Never-married")
    elif df['Marital Status'][i] == " Separated":
        Array[4] += 1
        if "Separated" not in LabelList:
            LabelList.append("Separated")
    elif df['Marital Status'][i] == " Married-AF-spouse":
        Array[5] += 1
        if "Married-AF-spouse" not in LabelList:
            LabelList.append("Married-AF-spouse")
    elif df['Marital Status'][i] == " Widowed":
        Array[6] += 1
        if "Widowed" not in LabelList:
            LabelList.append("Widowed")
    elif df['Marital Status'][i] == "Never-married":
        Array[3] += 1
        
fig, ax1 = plt.subplots(figsize = (24,12)) 
ax1.pie(Array, autopct= "%.1f%%" )
ax1.legend(LabelList, loc = "upper right", fontsize = 16)
plt.title("Family Obligations", fontsize = 24)
plt.axis('equal')
plt.show()

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
Array14 = [0] * 4
count14 = 0
Array56 = [0] * 4
count56 = 0
Array78 = [0] * 4
count78 = 0
Array9 = [0] * 4
count9 = 0
Array10 = [0] * 4
count10 = 0
Array11 = [0] * 4
count11 = 0
Array12 = [0] * 4
count12 = 0
ArrayAssoc = [0] * 4
countAssoc = 0
ArrayHS = [0] * 4
countHS = 0
ArraySC = [0] * 4
countSC = 0
ArrayB = [0] * 4
countB = 0
ArrayM = [0] * 4
countM = 0
ArrayPre = [0] * 4
countPre = 0
ArrayProf = [0] * 4
countProf = 0
ArrayDoc = [0] * 4
countDoc = 0
Labels = []
for i in range(0, len(df), 1):
    if df['Education'][i] == "Bachelors" or df['Education'][i] == " Bachelors":
        countB += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayB[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayB[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayB[2] += 1
        else:
            ArrayB[3] += 1
    elif df['Education'][i] == " HS-grad":
        countHS += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayHS[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayHS[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayHS[2] += 1
        else:
            ArrayHS[3] += 1
    elif df['Education'][i] == " Preschool":
        countPre += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayPre[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayPre[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayPre[2] += 1
        else:
            ArrayPre[3] += 1
    elif df['Education'][i] == " 5th-6th":
        count56 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array56[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array56[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array56[2] += 1
        else:
            Array56[3] += 1
    elif df['Education'][i] == " 1st-4th":
        count14 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array14[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array14[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array14[2] += 1
        else:
            Array14[3] += 1
    elif df['Education'][i] == " 7th-8th":
        count78 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array78[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array78[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array78[2] += 1
        else:
            Array78[3] += 1
    elif df['Education'][i] == " 9th":
        count9 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array9[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array9[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array9[2] += 1
        else:
            Array9[3] += 1
    elif df['Education'][i] == " 10th":
        count10 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array10[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array10[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array10[2] += 1
        else:
            Array10[3] += 1
    elif df['Education'][i] == " 11th":
        count11 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array11[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array11[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array11[2] += 1
        else:
            Array11[3] += 1
    elif df['Education'][i] == " 12th":
        count12 += 1
        if int(df['Hours Per Week'][i]) <= 30:
            Array12[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            Array12[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            Array12[2] += 1
        else:
            Array12[3] += 1
    elif df['Education'][i] == " Assoc-acdm" or df['Education'][i] == "Assoc-voc":
        countAssoc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayAssoc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayAssoc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayAssoc[2] += 1
        else:
            ArrayAssoc[3] += 1
    elif df['Education'][i] == " Some-college":
        countSC += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArraySC[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArraySC[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArraySC[2] += 1
        else:
            ArraySC[3] += 1
    elif df['Education'][i] == " Masters":
        countM += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayM[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayM[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayM[2] += 1
        else:
            ArrayM[3] += 1
    elif df['Education'][i] == " Prof-school":
        countProf += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayProf[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayProf[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayProf[2] += 1
        else:
            ArrayProf[3] += 1
    elif df['Education'][i] == " Doctorate":
        countDoc += 1
        if int(df['Hours Per Week'][i]) <= 30:
            ArrayDoc[0] += 1
        elif int(df['Hours Per Week'][i]) <= 40:
            ArrayDoc[1] += 1
        elif int(df['Hours Per Week'][i]) <= 80:
            ArrayDoc[2] += 1
        else:
            ArrayDoc[3] += 1
List = []
for i in range(0, len(df), 1):
    if df['Education'][i] not in List:
        List.append(df['Education'][i])
thirtyhours = []
fortyhours = []
eightyhours = []
more = []
for i in range(0, 4, 1):
    if i == 0:
        thirtyhours.append(ArrayPre[i] / countPre)
        thirtyhours.append(Array14[i] / count14)
        thirtyhours.append(Array56[i] / count56)
        thirtyhours.append(Array78[i] / count78)
        thirtyhours.append(Array9[i] / count9)
        thirtyhours.append(Array10[i] / count10)
        thirtyhours.append(Array11[i] / count11)
        thirtyhours.append(Array12[i] / count12)
        thirtyhours.append(ArrayHS[i] / countHS)
        thirtyhours.append(ArraySC[i] / countSC)
        thirtyhours.append(ArrayAssoc[i] / countAssoc)
        thirtyhours.append(ArrayB[i] / countB)
        thirtyhours.append(ArrayM[i] / countM)
        thirtyhours.append(ArrayProf[i] / countProf)
        thirtyhours.append(ArrayDoc[i] / countDoc)
    if i == 1:
        fortyhours.append(ArrayPre[i] / countPre)
        fortyhours.append(Array14[i] / count14)
        fortyhours.append(Array56[i] / count56)
        fortyhours.append(Array78[i] / count78)
        fortyhours.append(Array9[i] / count9)
        fortyhours.append(Array10[i] / count10)
        fortyhours.append(Array11[i] / count11)
        fortyhours.append(Array12[i] / count12)
        fortyhours.append(ArrayHS[i] / countHS)
        fortyhours.append(ArraySC[i] / countSC)
        fortyhours.append(ArrayAssoc[i] / countAssoc)
        fortyhours.append(ArrayB[i] / countB)
        fortyhours.append(ArrayM[i] / countM)
        fortyhours.append(ArrayProf[i] / countProf)
        fortyhours.append(ArrayDoc[i] / countDoc)
    if i == 2:
        eightyhours.append(ArrayPre[i] / countPre)
        eightyhours.append(Array14[i] / count14)
        eightyhours.append(Array56[i] / count56)
        eightyhours.append(Array78[i] / count78)
        eightyhours.append(Array9[i] / count9)
        eightyhours.append(Array10[i] / count10)
        eightyhours.append(Array11[i] / count11)
        eightyhours.append(Array12[i] / count12)
        eightyhours.append(ArrayHS[i] / countHS)
        eightyhours.append(ArraySC[i] / countSC)
        eightyhours.append(ArrayAssoc[i] / countAssoc)
        eightyhours.append(ArrayB[i] / countB)
        eightyhours.append(ArrayM[i] / countM)
        eightyhours.append(ArrayProf[i] / countProf)
        eightyhours.append(ArrayDoc[i] / countDoc)
    if i == 3:
        more.append(ArrayPre[i] / countPre)
        more.append(Array14[i] / count14)
        more.append(Array56[i] / count56)
        more.append(Array78[i] / count78)
        more.append(Array9[i] / count9)
        more.append(Array10[i] / count10)
        more.append(Array11[i] / count11)
        more.append(Array12[i] / count12)
        more.append(ArrayHS[i] / countHS)
        more.append(ArraySC[i] / countSC)
        more.append(ArrayAssoc[i] / countAssoc)
        more.append(ArrayB[i] / countB)
        more.append(ArrayM[i] / countM)
        more.append(ArrayProf[i] / countProf)
        more.append(ArrayDoc[i] / countDoc)
q = ["PreSchool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th", "High School Grad", "Some College", "Associate's Degree", "Bachelor's Degree", "Master's Degree", "Professional School", "Doctorate"]
List = []
List.append(" < 30")
List.append("30-40")
List.append("40-80")
List.append("80+")
for i in range(0, 4, 1):
    if i == 0:
        extradf1 = pd.DataFrame(np.c_[thirtyhours[0], thirtyhours[1], thirtyhours[2], thirtyhours[3], thirtyhours[4], thirtyhours[5], thirtyhours[6], thirtyhours[7], thirtyhours[8], thirtyhours[9], thirtyhours[10], thirtyhours[11], thirtyhours[12], thirtyhours[13], thirtyhours[14]], index = [" < 30"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours worked by Education'))
        plt.show()
        plt.close()
    if i == 1:
        extradf1 = pd.DataFrame(np.c_[fortyhours[0], fortyhours[1], fortyhours[2], fortyhours[3], fortyhours[4], fortyhours[5], fortyhours[6], fortyhours[7], fortyhours[8], fortyhours[9], fortyhours[10], fortyhours[11], fortyhours[12], fortyhours[13], fortyhours[14]], index = ["30 - 40"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours worked by Education'))
        plt.show()
        plt.close()
    if i == 2:
        extradf1 = pd.DataFrame(np.c_[eightyhours[0], eightyhours[1], eightyhours[2], eightyhours[3], eightyhours[4], eightyhours[5], eightyhours[6], eightyhours[7], eightyhours[8], eightyhours[9], eightyhours[10], eightyhours[11], eightyhours[12], eightyhours[13], eightyhours[14]], index = ["40-80"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours worked by Education'))
        plt.show()
        plt.close()
    if i == 3:
        extradf1 = pd.DataFrame(np.c_[more[0], more[1], more[2],more[3], more[4], more[5], more[6], more[7], more[8], more[9], more[10], more[11], more[12], more[13], more[14]], index = ["80+"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours worked by Education'))
        plt.show()
        plt.close()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:336: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:346: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
EmpList = []
for i in range(0, len(df), 1):
    if (df['Employment'][i][1::]) not in EmpList:
        EmpList.append(df['Employment'][i][1::])
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
for i in range(0, len(df), 1):
    for q in range(0, len(EmpList), 1):
        if (df['Employment'][i][1::]) == EmpList[q]:
            if q == 0:
                count1 += 1
            elif q == 1:
                count2 += 1
            elif q == 2:
                count3 += 1
            elif q == 3:
                count4 += 1
            elif q == 4:
                count5 += 1
            elif q == 5:
                count6 += 1
            elif q == 6:
                count7 += 1
            elif q == 7:
                count8 += 1
            elif q == 8:
                count9 += 1
Array1 = [0] * 4
Array2 = [0] * 4
Array3 = [0] * 4
Array4 = [0] * 4
Array5 = [0] * 4
Array6 = [0] * 4
Array7 = [0] * 4
Array8 = [0] * 4
Array9 = [0] * 4
for i in range(0, len(df), 1):
    for q in range(0, len(EmpList), 1):
        if q == 0:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
                if int(df['Hours Per Week'][i]) <= 30:
                    Array1[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array1[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array1[2] += 1
                else:
                    Array1[3] += 1
        if q == 1:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
                if int(df['Hours Per Week'][i]) <= 30:
                    Array2[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array2[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array2[2] += 1
                else:
                    Array2[3] += 1
        if q == 2:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array3[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array3[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array3[2] += 1
                else:
                    Array3[3] += 1
        if q == 3:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array4[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array4[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array4[2] += 1
                else:
                    Array4[3] += 1
        if q == 4:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array5[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array5[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array5[2] += 1
                else:
                    Array5[3] += 1
        if q == 5:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array6[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array6[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array6[2] += 1
                else:
                    Array6[3] += 1
        if q == 6:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array7[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array7[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array7[2] += 1
                else:
                    Array7[3] += 1
        if q == 7:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array8[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array8[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array8[2] += 1
                else:
                    Array8[3] += 1
        if q == 8:
            if (df['Employment'][i][1::]) == EmpList[q] or df['Employment'][i] == EmpList[q]:
            
                if int(df['Hours Per Week'][i]) <= 30:
                    Array9[0] += 1
                elif int(df['Hours Per Week'][i]) <= 40:
                    Array9[1] += 1
                elif int(df['Hours Per Week'][i]) <= 80:
                    Array9[2] += 1
                else:
                    Array9[3] += 1
thirtyhours = []
fortyhours = []
eightyhours = []
more = []
for i in range(0, 4, 1):
    if i == 0:
        thirtyhours.append(Array1[i] / count1)
        thirtyhours.append(Array2[i] / count2)
        thirtyhours.append(Array3[i] / count3)
        thirtyhours.append(Array4[i] / count4)
        thirtyhours.append(Array5[i] / count5)
        thirtyhours.append(Array6[i] / count6)
        thirtyhours.append(Array7[i] / count7)
        thirtyhours.append(Array8[i] / count8)
        thirtyhours.append(Array9[i] / count9)
        
    if i == 1:
        fortyhours.append(Array1[i] / count1)
        fortyhours.append(Array2[i] / count2)
        fortyhours.append(Array3[i] / count3)
        fortyhours.append(Array4[i] / count4)
        fortyhours.append(Array5[i] / count5)
        fortyhours.append(Array6[i] / count6)
        fortyhours.append(Array7[i] / count7)
        fortyhours.append(Array8[i] / count8)
        fortyhours.append(Array9[i] / count9)
        
    if i == 2:
        eightyhours.append(Array1[i] / count1)
        eightyhours.append(Array2[i] / count2)
        eightyhours.append(Array3[i] / count3)
        eightyhours.append(Array4[i] / count4)
        eightyhours.append(Array5[i] / count5)
        eightyhours.append(Array6[i] / count6)
        eightyhours.append(Array7[i] / count7)
        eightyhours.append(Array8[i] / count8)
        eightyhours.append(Array9[i] / count9)
       
    if i == 3:
        more.append(Array1[i] / count1)
        more.append(Array2[i] / count2)
        more.append(Array3[i] / count3)
        more.append(Array4[i] / count4)
        more.append(Array5[i] / count5)
        more.append(Array6[i] / count6)
        more.append(Array7[i] / count7)
        more.append(Array8[i] / count8)
        more.append(Array9[i] / count9)
        
q = EmpList
List = []
List.append(" < 30")
List.append("30-40")
List.append("40-80")
List.append("80+")
for i in range(0, 4, 1):
    if i == 0:
        extradf1 = pd.DataFrame(np.c_[thirtyhours[0], thirtyhours[1], thirtyhours[2], thirtyhours[3], thirtyhours[4], thirtyhours[5], thirtyhours[6], thirtyhours[7], thirtyhours[8]], index = [" < 30"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours Worked by Job Classification'))
        plt.show()
        plt.close()
    if i == 1:
        extradf1 = pd.DataFrame(np.c_[fortyhours[0], fortyhours[1], fortyhours[2], fortyhours[3], fortyhours[4], fortyhours[5], fortyhours[6], fortyhours[7], fortyhours[8]], index = ["30 - 40"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours Worked by Job Classification'))
        plt.show()
        plt.close()
    if i == 2:
        extradf1 = pd.DataFrame(np.c_[eightyhours[0], eightyhours[1], eightyhours[2], eightyhours[3], eightyhours[4], eightyhours[5], eightyhours[6], eightyhours[7], eightyhours[8]], index = ["40-80"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours Worked by Job Classification'))
        plt.show()
        plt.close()
    if i == 3:
        extradf1 = pd.DataFrame(np.c_[more[0], more[1], more[2],more[3], more[4], more[5], more[6], more[7], more[8]], index = ["80+"])
        extradf1.plot.bar()
        ax = plt.subplot(111)
        ax.legend(q, loc='center left', bbox_to_anchor=(1, 0.5))
        plt.xticks(rotation=0)
        plt.ylabel('Percent of People')
        plt.title(('Hours Worked by Job Classification'))
        plt.show()
        plt.close()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:41: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
lessthan50ed = []
countlessthan50ed = 0
greaterthan50ed = []
countgreaterthan50ed = 0
lessthan50noed = []
countlessthan50noed = 0
greaterthan50noed = []
countgreaterthan50noed = 0
countBeyond = 0
countA = 0
for i in range(0, len(df), 1):
    if df['Education'][i] == "Bachelors" or df['Education'][i] == " Bachelors" or df['Education'][i] == " Assoc-acdm" or df['Education'][i] == "Assoc-voc" or df['Education'][i] == " Doctorate" or df['Education'][i] == " Prof-school" or df['Education'][i] == " Masters":
        countBeyond += 1
        if (df['Income'][i]) == " >50K":
            lessthan50ed.append(df['Education'][i])
            countlessthan50ed += 1
        elif (df['Income'][i]) == "<=50K" or df['Income'][i] == ' <=50K':
            greaterthan50ed.append(df['Education'][i])
            countgreaterthan50ed += 1
            
    elif df['Education'][i] == " HS-grad" or df['Education'][i] == " Preschool" or df['Education'][i] == " Some-college" or df['Education'][i] == " 5th-6th" or df['Education'][i] == " 1st-4th" or df['Education'][i] == " 7th-8th" or df['Education'][i] == " 9th" or df['Education'][i] == " 10th" or df['Education'][i] == " 11th" or df['Education'][i] == " 12th":
        countA += 1
        if (df['Income'][i]) == " >50K":
            lessthan50noed.append(df['Education'][i])
            countlessthan50noed += 1
        elif (df['Income'][i]) == "<=50K" or df['Income'][i] == ' <=50K':
            greaterthan50noed.append(df['Education'][i])
            countgreaterthan50noed += 1
            
less50edpercent = countlessthan50ed / countBeyond
greater50edpercent = countgreaterthan50ed / countBeyond
less50noedpercent = countlessthan50noed / countA
greater50noedpercent = countgreaterthan50noed / countA  
dfList = []
for i in range(0, len(df), 1):
    if df['Income'][i] not in dfList:
        dfList.append(df['Income'][i])

fig = plt.figure()
objects = ('Greater Than 50k No Ed', 'Less Than 50k No Ed', 'Greater Than 50k College Grad', 'Less Than 50k College Grad')
y_pos = np.arange(len(objects))
performance = [less50noedpercent,greater50noedpercent,less50edpercent,greater50edpercent]
plt.barh(y_pos, performance, color = "red")
plt.yticks(y_pos, objects)
plt.title("Income Disparity")
plt.xlabel("Percent in Category")
plt.show()

# %%
import pandas as pd
table = pd.read_table("/Users/brendanmassey/Downloads/adult.names")
table2 = pd.read_table("/Users/brendanmassey/Downloads/adult.test")
table3 = pd.read_table("/Users/brendanmassey/Downloads/adult.data")
x = []
for i in range(0, len(table3), 1):
    x.append(table3["39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K"][i].split(","))
Age = []
Employment = []
Number = []
Ed = []
Number2 = []
MarriageStatus = []
Level = []
Spousal = []
Race = []
Sex = []
value1 = []
value2 = []
value3 = []
Country = []
Income = []
for i in range(0, len(x), 1):
    Age.append(x[i][0])
    Number.append(x[i][2])
    Employment.append(x[i][1])
    Ed.append(x[i][3])
    Number2.append(x[i][4])
    MarriageStatus.append(x[i][5])
    Level.append(x[i][6])
    Spousal.append(x[i][7])
    Race.append(x[i][8])
    Sex.append(x[i][9])
    value1.append(x[i][10])
    value2.append(x[i][11])
    value3.append(x[i][12])
    Country.append(x[i][13])
    Income.append(x[i][14])
    
Age.append(39)
Employment.append("State-gov")
Number.append(77516)
Ed.append("Bachelors")
Number2.append(13)
MarriageStatus.append("Never-married")
Level.append("Adm-clerical")
Spousal.append("Not-in-family")
Race.append("White")
Sex.append("Male")
value1.append(2174)
value2.append(0)
value3.append(40)
Country.append("United-States")
Income.append("<=50K")
df = pd.DataFrame()
df['Age'] = Age
df['Number'] = Number
df['Education'] = Ed
df['Employment'] = Employment
df['Number2'] = Number2
df['Marital Status'] = MarriageStatus
df['Job Level'] = Level
df['Familial Role'] = Spousal
df['Race'] = Race
df['Sex'] = Sex
df['Capital Gains'] = value1
df['Capital Loss'] = value2
df['Hours Per Week'] = value3
df['Country'] = Country
df['Income'] = Income
Array14 = 0
count14 = 0
Array56 = 0
count56 = 0
Array78 = 0
count78 = 0
Array9 = 0
count9 = 0
Array10 = 0
count10 = 0
Array11 = 0
count11 = 0
Array12 = 0
count12 = 0
ArrayAssoc = 0
countAssoc = 0
ArrayHS = 0
countHS = 0
ArraySC = 0
countSC = 0
ArrayB = 0
countB = 0
ArrayM = 0
countM = 0
ArrayPre = 0
countPre = 0
ArrayProf = 0
countProf = 0
ArrayDoc = 0
countDoc = 0
Labels = []
for i in range(0, len(df), 1):
    if df['Education'][i] == "Bachelors" or df['Education'][i] == " Bachelors":
        countB += 1
        if (df['Income'][i]) == " >50K":
            ArrayB += 1
    elif df['Education'][i] == " HS-grad":
        countHS += 1
        if (df['Income'][i]) == " >50K":
            ArrayHS += 1
    elif df['Education'][i] == " Preschool":
        countPre += 1
        if (df['Income'][i]) == " >50K":
            ArrayPre += 1
    elif df['Education'][i] == " 5th-6th":
        count56 += 1
        if (df['Income'][i]) == " >50K":
            Array56 += 1
    elif df['Education'][i] == " 1st-4th":
        count14 += 1
        if (df['Income'][i]) == " >50K":
            Array14 += 1
        
    elif df['Education'][i] == " 7th-8th":
        count78 += 1
        if (df['Income'][i]) == " >50K":
            Array78 += 1
        
    elif df['Education'][i] == " 9th":
        count9 += 1
        if (df['Income'][i]) == " >50K":
            Array9 += 1
        
    elif df['Education'][i] == " 10th":
        count10 += 1
        if (df['Income'][i]) == " >50K":
            Array10 += 1
        
    elif df['Education'][i] == " 11th":
        count11 += 1
        if (df['Income'][i]) == " >50K":
            Array11 += 1
    elif df['Education'][i] == " 12th":
        count12 += 1
        if (df['Income'][i]) == " >50K":
            Array12 += 1
    elif df['Education'][i] == " Assoc-acdm" or df['Education'][i] == "Assoc-voc":
        countAssoc += 1
        if (df['Income'][i]) == " >50K":
            ArrayAssoc += 1
        
    elif df['Education'][i] == " Some-college":
        countSC += 1
        if (df['Income'][i]) == " >50K":
            ArraySC += 1
        
    elif df['Education'][i] == " Masters":
        countM += 1
        if (df['Income'][i]) == " >50K":
            ArrayM += 1
    elif df['Education'][i] == " Prof-school":
        countProf += 1
        if (df['Income'][i]) == " >50K":
            ArrayProf += 1
        
    elif df['Education'][i] == " Doctorate":
        countDoc += 1
        if (df['Income'][i]) == " >50K":
            ArrayDoc += 1
SchoolPCPerc = ArrayPre / countPre
School14Perc = Array14 / count14
School56Perc = Array56 / count56
School78Perc = Array78 / count78
School9Perc = Array9 / count9
School10Perc = Array10 / count10
School11Perc = Array11 / count11
School12Perc = Array12 / count12
SchoolSCPerc = ArraySC / countSC
SchoolAPerc = ArrayAssoc / countAssoc
SchoolBPerc = ArrayB / countB
SchoolMPerc = ArrayM / countM
SchoolProfPerc = ArrayProf / countProf
SchoolDocPerc = ArrayDoc / countDoc  

A1 = [SchoolPCPerc, School14Perc, School56Perc, School78Perc,School9Perc,School10Perc,School11Perc,School12Perc,SchoolSCPerc, SchoolAPerc, SchoolBPerc,SchoolMPerc,SchoolProfPerc,SchoolDocPerc]
label = ["PreSchool", "1st - 4th Grade", "5th - 6th Grade", "7th - 8th Grade", "9th Grade", "10th Grade", "11th Grade", "12th Grade", "Some-College", "Associate's", "Bachelor's", "Master's", "Professional", "Doctorate"]
plt.ylabel('Percent')
plt.xticks(rotation=45)
plt.plot(label, A1)
plt.title("Percent Making More Than 50k/year by Educational Level")
plt.show()
